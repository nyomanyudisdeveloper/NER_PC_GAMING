# %% [markdown]
# ### ***1. Import Libraries***

# %% [markdown]
# ----

# %%
import pandas as pd
# import tensorflow_hub as tf_hub

import math

from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %% [markdown]
# ----
# ----

# %% [markdown]
# <vspace>

# %% [markdown]
# ### ***2.Load Data***

# %% [markdown]
# ----

# %%
# load data from file question.csv
df = pd.read_csv("../dataset/question.csv")
df
# Out:
#                                                question
# 0       Forza horizon 5 bsa om .bsa skalian di install?
# 1                 gan itu pc only udah sama dalemannya?
# 2     gan, bisa maenin game EA FC 24 dan call of dut...
# 3                  gan ini kalo buat pb atau gta 5 bisa
# 4     Bisa installin ets2 dan gta roleplay?? Sisanya...
# ...                                                 ...
# 1552  gan kalo di pake game microsoft flight simulat...
# 1553  Min minecraft berapa fps tolong ya min mau bel...
# 1554  Min untuk hardisk-nya kalau diubah ke 1TB apa ...
# 1555                  kalo ada yg mau di ubah bisa min?
# 1556                                     Ini ready gan?
#
# [1557 rows x 1 columns]

# %% [markdown]
# #### ***2.1 Handling Data Duplicate***

# %%
# Check data duplicated
df.duplicated().sum()
# Out:
# 166

# %%
# Remove data duplicate
df = df.drop_duplicates(ignore_index=True)

# %%
# Check data duplicated
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### ***2.2 Handling Missing Value***

# %%
# Check Missing Value
df.isnull().sum()
# Out:
# question    0
# dtype: int64

# %%
# Handling missing value by delete it
df.dropna(inplace=True)

# %% [markdown]
# ----
# ----

# %% [markdown]
# <vspace>

# %% [markdown]
# ### ***3.Preprocessing Data***

# %% [markdown]
# ----

# %% [markdown]
# #### ***3.1 Replace enter into space***

# %%
# Check if question has newline
df[df['question'].str.contains("\n")]
# Out:
#                                                question
# 5     bang kalo beli gamenya bisa di ilangin?\nsaya ...
# 17    sore gan \napakah pc nya masih ada \nterima kasih
# 24    bisa di kirim ke tangsel?\nrequest game maks brp?
# 26    Pagi, mo nanya dong gan\n1. Barangnya baru sem...
# 84    Buat editing video gmn gan?\nAtau bisa di reko...
# ...                                                 ...
# 1278  1. ka ini vga nya kita yg pilih diantara 3 itu...
# 1289  kak untuk spek yang kayak gini ada gak/spek pr...
# 1300  kak kalo memorynya itu DDR4 \nvga 4gb ddr5 ber...
# 1302  apakah vga bisa di upgrade?\n\nada slot tambah...
# 1304  monitor nya merek apa.\ntambahin JNE cargo don...
#
# [62 rows x 1 columns]

# %%
# Replace newline into space
df['question'] = df['question'].str.replace('\n',' ')
# Out:
# /var/folders/cr/8g19f6x13sn907v0ff4vkmm80000gn/T/ipykernel_19158/1575271079.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['question'] = df['question'].str.replace('\n',' ')

# %%
# Check if question has newline
df[df['question'].str.contains("\n")]
# Out:
# Empty DataFrame
# Columns: [question]
# Index: []

# %% [markdown]
# <vspace>

# %% [markdown]
# #### ***3.2 Remove unnecessary characters (Only alphabetic remaining)***

# %%
# show top 5 data in df
df.head()
# Out:
#                                             question
# 0    Forza horizon 5 bsa om .bsa skalian di install?
# 1              gan itu pc only udah sama dalemannya?
# 2  gan, bisa maenin game EA FC 24 dan call of dut...
# 3               gan ini kalo buat pb atau gta 5 bisa
# 4  Bisa installin ets2 dan gta roleplay?? Sisanya...

# %%
def clean_special_character(text):
    '''
    This function is used to transofrm text so there are no special character ( alphabetic and numeric only)

    parameter description
    ===========================
    text = question or regular sentence 

    usage example 
    ===================
    data_inferential = "untuk record MLBB dan PUBG kuat kah gan??"
    data_inferential = clean_special_character(data_inferential)
    '''
    result = "";
    for char in text:
        if (char == " " or char.isalpha()) and char != "²":
            result+= char
        else:
            result += " "
    return result
df['question_after_preprocessing'] = df['question'].apply(clean_special_character)
# Out:
# /var/folders/cr/8g19f6x13sn907v0ff4vkmm80000gn/T/ipykernel_19158/1291111100.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['question_after_preprocessing'] = df['question'].apply(clean_special_character)

# %%
df.head()
# Out:
#                                             question  \
# 0    Forza horizon 5 bsa om .bsa skalian di install?
# 1              gan itu pc only udah sama dalemannya?
# 2  gan, bisa maenin game EA FC 24 dan call of dut...
# 3               gan ini kalo buat pb atau gta 5 bisa
# 4  Bisa installin ets2 dan gta roleplay?? Sisanya...
#
#                         question_after_preprocessing
# 0    Forza horizon   bsa om  bsa skalian di install
# 1              gan itu pc only udah sama dalemannya
# 2  gan  bisa maenin game EA FC    dan call of dut...
# 3               gan ini kalo buat pb atau gta   bisa
# 4  Bisa installin ets  dan gta roleplay   Sisanya...

# %% [markdown]
# <vspace>

# %% [markdown]
# #### ***3.3 Change letters to lowercase***

# %% [markdown]
# -----

# %%
# show top 5 data in df
df.head()
# Out:
#                                             question  \
# 0    Forza horizon 5 bsa om .bsa skalian di install?
# 1              gan itu pc only udah sama dalemannya?
# 2  gan, bisa maenin game EA FC 24 dan call of dut...
# 3               gan ini kalo buat pb atau gta 5 bisa
# 4  Bisa installin ets2 dan gta roleplay?? Sisanya...
#
#                         question_after_preprocessing
# 0    Forza horizon   bsa om  bsa skalian di install
# 1              gan itu pc only udah sama dalemannya
# 2  gan  bisa maenin game EA FC    dan call of dut...
# 3               gan ini kalo buat pb atau gta   bisa
# 4  Bisa installin ets  dan gta roleplay   Sisanya...

# %%
# Change question text to lower case
df['question_after_preprocessing'] = df['question_after_preprocessing'].apply(lambda x: " ".join(x.lower() for x in x.split()))
# Out:
# /var/folders/cr/8g19f6x13sn907v0ff4vkmm80000gn/T/ipykernel_19158/1256908210.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['question_after_preprocessing'] = df['question_after_preprocessing'].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %%
# show top 5 data in df
df.head()
# Out:
#                                             question  \
# 0    Forza horizon 5 bsa om .bsa skalian di install?
# 1              gan itu pc only udah sama dalemannya?
# 2  gan, bisa maenin game EA FC 24 dan call of dut...
# 3               gan ini kalo buat pb atau gta 5 bisa
# 4  Bisa installin ets2 dan gta roleplay?? Sisanya...
#
#                         question_after_preprocessing
# 0        forza horizon bsa om bsa skalian di install
# 1               gan itu pc only udah sama dalemannya
# 2  gan bisa maenin game ea fc dan call of duty mo...
# 3                 gan ini kalo buat pb atau gta bisa
# 4  bisa installin ets dan gta roleplay sisanya ko...

# %% [markdown]
# <vspace>

# %% [markdown]
# #### ***3.4 Remove White Spaces***

# %% [markdown]
# ----

# %%
# Check data if there is question with whitespace
df[(df['question_after_preprocessing'].str.get(0) == ' ') | (df['question_after_preprocessing'].str.get(-1) == ' ')]
# Out:
# Empty DataFrame
# Columns: [question, question_after_preprocessing]
# Index: []

# %%
# Remove white space in df question text 
df['question_after_preprocessing'] = df['question_after_preprocessing'].str.strip()
# Out:
# /var/folders/cr/8g19f6x13sn907v0ff4vkmm80000gn/T/ipykernel_19158/1017180767.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['question_after_preprocessing'] = df['question_after_preprocessing'].str.strip()

# %%
# Check data if there is question with whitespace
df[(df['question_after_preprocessing'].str.get(0) == ' ') | (df['question_after_preprocessing'].str.get(-1) == ' ')]
# Out:
# Empty DataFrame
# Columns: [question, question_after_preprocessing]
# Index: []

# %% [markdown]
# #### ***3.5 Create dataframe for tagging/labeling Or Tokenization***

# %% [markdown]
# ----

# %%
# This cell code is used to convert data to tokenization
list_result = []
for index in df.index:
    list_word = df.iloc[index]['question_after_preprocessing'].split(" ")
    for word in list_word:
        list_result.append({
            'sentence':f'Kalimat {index+1}',
            'kata': word,
            'tag':''
        })
df_token = pd.DataFrame(list_result)
df_token
# Out:
#            sentence     kata tag
# 0         Kalimat 1    forza
# 1         Kalimat 1  horizon
# 2         Kalimat 1      bsa
# 3         Kalimat 1       om
# 4         Kalimat 1      bsa
# ...             ...      ...  ..
# 12104  Kalimat 1390     bisa
# 12105  Kalimat 1390      min
# 12106  Kalimat 1391      ini
# 12107  Kalimat 1391    ready
# 12108  Kalimat 1391      gan
#
# [12109 rows x 3 columns]

# %% [markdown]
# <vspace>

# %% [markdown]
# <vspace>

# %% [markdown]
# #### ***3.6 Change Slang Word into Normal***

# %% [markdown]
# ----

# %%
# read file csv for slang dictionary 
slang = pd.read_csv("../dataset/Slang2.csv")
slang_dict = dict(zip(slang['slang'], slang['formal']))

# del specific key because it is not neccessary for PC GAMING NER scenario 
del slang_dict['main']
del slang_dict['banget']
del slang_dict['uhh']
del slang_dict['takut']
del slang_dict['da']
del slang_dict['uhhh']

# edit specific key in slang_dict 
slang_dict['dahhhh'] = 'sudah'
slang_dict['kalo'] = 'kalau'

# %%
# THis notebook is used to check if there is slang word in df_token
def check_slang_word(word):
    steming_slang = slang_dict.get(word)
    if steming_slang == None:
        return 
    else:
        try:
            if(math.isnan(steming_slang)):
                return
            else:
                print(f"{word} should be {steming_slang}")
                return steming_slang
        except:
            print(f"{word} should be {steming_slang}")
            return steming_slang
        
df_token['kata'].apply(check_slang_word)
# Out:
# bsa should be bisa
# bsa should be bisa
# skalian should be  sekalian
# udah should be sudah
# ea should be iya
# kalo should be kalau
# kalo should be kalau
# gak should be tidak
# ori should be orisinal
# c should be sih
# gk should be tidak
# kalo should be kalau
# kalo should be kalau
# trus should be terus
# gk should be tidak
# smpe should be sampai
# k should be ke
# klau should be kalau
# w should be saya
# gk should be tidak
# ga should be tidak
# brapa should be berapa
# utk should be  untuk
# klo should be kalau
# d should be di
# yg should be yang
# tdk should be tidak
# kalo should be kalau
# nambah should be menambah
# brp should be berapa
# ori should be orisinal
# kalo should be kalau
# g should be begitu
# gak should be tidak
# nambah should be menambah
# brp should be berapa
# brp should be berapa
# mo should be mau
# ori should be orisinal
# ms should be masih
# ori should be orisinal
# thn should be tahun
# jkt should be jakarta
# brp should be berapa
# yah should be iya
# ap should be apa
# brpa should be berapa
# boss should be bos
# brp should be berapa
# gk should be tidak
# kalo should be kalau
# gak should be tidak
# gt should be begitu
# udah should be sudah
# maen should be main
# ga should be tidak
# ni should be nih
# ka should be kak
# gak should be tidak
# gak should be tidak
# klo should be kalau
# k should be ke
# ga should be tidak
# klw should be kalau
# bsa should be bisa
# ga should be tidak
# ka should be kak
# brapa should be berapa
# gk should be tidak
# gak should be tidak
# liat should be lihat
# kalo should be kalau
# ama should be sama
# nggak should be tidak
# sy should be saya
# tp should be tapi
# kalo should be kalau
# gini should be begini
# d should be di
# ga should be tidak
# pengen should be mau
# yahh should be ya
# dapet should be dapat
# udah should be sudah
# gk should be tidak
# bsa should be bisa
# g should be begitu
# ori should be orisinal
# aja should be saja
# brapa should be berapa
# klo should be kalau
# pake should be pakai
# gak should be tidak
# kn should be kan
# gk should be tidak
# bg should be abang
# ama should be sama
# gak should be tidak
# gak should be tidak
# beneran should be benaran
# gak should be tidak
# brp should be berapa
# kalo should be kalau
# ngak should be tidak
# gk should be tidak
# ga should be tidak
# klo should be kalau
# ga should be tidak
# udh should be sudah
# gmn should be bagaimana
# boss should be bos
# ga should be tidak
# gak should be tidak
# kalo should be kalau
# pake should be pakai
# klo should be kalau
# brp should be berapa
# ga should be tidak
# kalo should be kalau
# brp should be berapa
# milih should be memilih
# engga should be tidak
# kalo should be kalau
# jd should be jadi
# brp should be berapa
# gak should be tidak
# kalo should be kalau
# kalo should be kalau
# brp should be berapa
# brp should be berapa
# g should be begitu
# yg should be yang
# brpa should be berapa
# brp should be berapa
# aja should be saja
# ga should be tidak
# ga should be tidak
# kalo should be kalau
# pake should be pakai
# gak should be tidak
# gk should be tidak
# klo should be kalau
# dapet should be dapat
# diliat should be dilihat
# tp should be tapi
# utk should be  untuk
# yg should be yang
# brp should be berapa
# klo should be kalau
# dgn should be dengan
# yg should be yang
# nambah should be menambah
# brp should be berapa
# utk should be  untuk
# lg should be lagi
# brp should be berapa
# ga should be tidak
# yg should be yang
# dpt should be dapat
# kalo should be kalau
# gak should be tidak
# yg should be yang
# gak should be tidak
# gk should be tidak
# utk should be  untuk
# ga should be tidak
# gimana should be bagaimana
# gitu should be begitu
# nambah should be menambah
# brp should be berapa
# jt should be juta
# boss should be bos
# yg should be yang
# nambah should be menambah
# brp should be berapa
# brp should be berapa
# jd should be jadi
# brpa should be berapa
# ga should be tidak
# brp should be berapa
# kk should be kakak
# bsa should be bisa
# yg should be yang
# ga should be tidak
# gak should be tidak
# ga should be tidak
# kalo should be kalau
# brp should be berapa
# brp should be berapa
# brp should be berapa
# brp should be berapa
# klau should be kalau
# sma should be sama
# dapet should be dapat
# yg should be yang
# yg should be yang
# brp should be berapa
# gak should be tidak
# ga should be tidak
# nambah should be menambah
# jd should be jadi
# dpt should be dapat
# brp should be berapa
# kalo should be kalau
# gausah should be tidak usah
# pake should be pakai
# ama should be sama
# yg should be yang
# nambah should be menambah
# pake should be pakai
# nggak should be tidak
# gt should be begitu
# gt should be begitu
# bener should be benar
# kalo should be kalau
# nambah should be menambah
# kalo should be kalau
# kalo should be kalau
# pakek should be pakai
# nunggu should be menunggu
# gt should be begitu
# brp should be berapa
# klo should be kalau
# ga should be tidak
# gak should be tidak
# ngedit should be mengedit
# gak should be tidak
# yah should be iya
# gt should be begitu
# nggak should be tidak
# dpt should be dapat
# ga should be tidak
# kalo should be kalau
# ga should be tidak
# ni should be nih
# kyk should be seperti
# dlu should be dulu
# sy should be saya
# gk should be tidak
# gak should be tidak
# ngga should be tidak
# gimana should be bagaimana
# gak should be tidak
# dapet should be dapat
# brp should be berapa
# d should be di
# brp should be berapa
# ps should be pas
# ps should be pas
# nggak should be tidak
# kalo should be kalau
# dapet should be dapat
# gt should be begitu
# gt should be begitu
# gt should be begitu
# ga should be tidak
# kalo should be kalau
# ga should be tidak
# t should be ta
# gak should be tidak
# nambah should be menambah
# udah should be sudah
# aja should be saja
# gak should be tidak
# nggak should be tidak
# dapet should be dapat
# gt should be begitu
# dapet should be dapat
# gt should be begitu
# kalo should be kalau
# nambah should be menambah
# ga should be tidak
# gak should be tidak
# kalo should be kalau
# tdk should be tidak
# aja should be saja
# gak should be tidak
# dpt should be dapat
# kalo should be kalau
# brp should be berapa
# gt should be begitu
# gak should be tidak
# gak should be tidak
# pengen should be mau
# d should be di
# kalo should be kalau
# dapet should be dapat
# gak should be tidak
# yg should be yang
# ato should be atau
# g should be begitu
# pke should be pakai
# aja should be saja
# gak should be tidak
# gak should be tidak
# gak should be tidak
# gk should be tidak
# brpa should be berapa
# gak should be tidak
# ga should be tidak
# yg should be yang
# t should be ta
# ga should be tidak
# yg should be yang
# nga should be tidak
# in should be ini
# ga should be tidak
# ga should be tidak
# t should be ta
# a should be allah
# t should be ta
# a should be allah
# g should be begitu
# kalo should be kalau
# udah should be sudah
# ngak should be tidak
# dapet should be dapat
# ga should be tidak
# in should be ini
# g should be begitu
# udah should be sudah
# kalo should be kalau
# gak should be tidak
# udah should be sudah
# dapet should be dapat
# tuk should be untuk
# gak should be tidak
# gak should be tidak
# kalo should be kalau
# ngga should be tidak
# udh should be sudah
# kk should be kakak
# ngedit should be mengedit
# dapet should be dapat
# nggk should be tidak
# ngedit should be mengedit
# nggk should be tidak
# dapet should be dapat
# gitu should be begitu
# kalo should be kalau
# ga should be tidak
# pake should be pakai
# gimana should be bagaimana
# gak should be tidak
# dmn should be dimana
# ga should be tidak
# yg should be yang
# yg should be yang
# dapet should be dapat
# brp should be berapa
# ngg should be tidak
# yah should be iya
# dah should be sudah
# ga should be tidak
# gk should be tidak
# gk should be tidak
# gak should be tidak
# jdi should be jadi
# gak should be tidak
# gk should be tidak
# in should be ini
# aja should be saja
# pake should be pakai
# kalo should be kalau
# dapet should be dapat
# dapet should be dapat
# gak should be tidak
# gmna should be bagaimana
# yg should be yang
# ga should be tidak
# nuduh should be menuduh
# kalo should be kalau
# dapet should be dapat
# ga should be tidak
# brp should be berapa
# dapet should be dapat
# kalo should be kalau
# nambah should be menambah
# bs should be bisa
# udah should be sudah
# dapet should be dapat
# ka should be kak
# udah should be sudah
# dapet should be dapat
# gak should be tidak
# trus should be terus
# dateng should be datang
# g should be begitu
# klo should be kalau
# sja should be saja
# ad should be ada
# gak should be tidak
# aja should be saja
# ga should be tidak
# yg should be yang
# udah should be sudah
# udah should be sudah
# ka should be kak
# yg should be yang
# mna should be mana
# yaa should be iya
# makasih should be terima kasih
# ga should be tidak
# kalo should be kalau
# ga should be tidak
# hallo should be halo
# ga should be tidak
# ka should be kak
# kalo should be kalau
# ga should be tidak
# klo should be kalau
# kn should be kan
# klau should be kalau
# gk should be tidak
# gitu should be begitu
# yg should be yang
# ga should be tidak
# gt should be begitu
# gak should be tidak
# dapet should be dapat
# gt should be begitu
# kalo should be kalau
# aja should be saja
# kalo should be kalau
# ga should be tidak
# yg should be yang
# kalo should be kalau
# utk should be  untuk
# yg should be yang
# ga should be tidak
# ga should be tidak
# kk should be kakak
# kalo should be kalau
# yg should be yang
# yg should be yang
# nggak should be tidak
# kk should be kakak
# gak should be tidak
# dipake should be dipakai
# kalo should be kalau
# yg should be yang
# mna should be mana
# engga should be tidak
# sdh should be sudah
# pake should be pakai
# ngga should be tidak
# ka should be kak
# y should be iya
# karna should be karena
# kalo should be kalau
# pke should be pakai
# ama should be sama
# kalo should be kalau
# yg should be yang
# dpt should be dapat
# brp should be berapa
# ga should be tidak
# kalo should be kalau
# k should be ke
# make should be memakai
# aja should be saja
# gak should be tidak
# yg should be yang
# gk should be tidak
# gak should be tidak
# kalo should be kalau
# nambah should be menambah
# kalo should be kalau
# udah should be sudah
# gak should be tidak
# pake should be pakai
# maen should be main
# sdh should be sudah
# kh should be kah
# gak should be tidak
# gt should be begitu
# yah should be iya
# gak should be tidak
# gak should be tidak
# udah should be sudah
# dpt should be dapat
# gak should be tidak
# gk should be tidak
# nambah should be menambah
# kalo should be kalau
# yg should be yang
# k should be ke
# blm should be belum
# nie should be nih
# maen should be main
# pa should be apa
# ja should be saja
# y should be iya
# dpt should be dapat
# aza should be saja
# add should be ada
# bs should be bisa
# pake should be pakai
# gak should be tidak
# ga should be tidak
# gk should be tidak
# bg should be abang
# kalo should be kalau
# pake should be pakai
# kalo should be kalau
# kalo should be kalau
# kalo should be kalau
# nambah should be menambah
# brapa should be berapa
# milih should be memilih
# yg should be yang
# milih should be memilih
# kalo should be kalau
# cr should be cara
# bener should be benar
# pake should be pakai
# jg should be juga
# gk should be tidak
# kalo should be kalau
# sm should be sama
# d should be di
# sprti should be seperti
# bsa should be bisa
# hallo should be halo
# make should be memakai
# ga should be tidak
# brp should be berapa
# klw should be kalau
# kalo should be kalau
# yg should be yang
# brp should be berapa
# nambah should be menambah
# klo should be kalau
# nambah should be menambah
# brp should be berapa
# yg should be yang
# jg should be juga
# yg should be yang
# jd should be jadi
# brp should be berapa
# ea should be iya
# udah should be sudah
# dapet should be dapat
# ka should be kak
# pake should be pakai
# ga should be tidak
# si should be sih
# yok should be mari
# yok should be mari
# masukin should be memasuki
# yg should be yang
# dgn should be dengan
# yg should be yang
# udah should be sudah
# yg should be yang
# kek should be seperti
# yg should be yang
# kalo should be kalau
# aja should be saja
# klo should be kalau
# d should be di
# yg should be yang
# udh should be sudah
# pake should be pakai
# pake should be pakai
# beneran should be benaran
# klo should be kalau
# utk should be  untuk
# yg should be yang
# dapet should be dapat
# yg should be yang
# gimana should be bagaimana
# gak should be tidak
# ka should be kak
# gmana should be bagaimana
# yg should be yang
# gak should be tidak
# gak should be tidak
# brp should be berapa
# yg should be yang
# kpn should be kapan
# kalo should be kalau
# pake should be pakai
# ngga should be tidak
# pake should be pakai
# gk should be tidak
# brapa should be berapa
# trus should be terus
# bsa should be bisa
# minta should be meminta
# nambah should be menambah
# gak should be tidak
# gimana should be bagaimana
# gak should be tidak
# bsa should be bisa
# k should be ke
# x should be kali
# ga should be tidak
# dpt should be dapat
# udah should be sudah
# berati should be berarti
# brp should be berapa
# kaya should be seperti
# kalo should be kalau
# ngedit should be mengedit
# gak should be tidak
# ka should be kak
# ga should be tidak
# dapet should be dapat
# gak should be tidak
# gak should be tidak
# nambah should be menambah
# brp should be berapa
# yg should be yang
# pake should be pakai
# yg should be yang
# gak should be tidak
# kalo should be kalau
# emang should be memang
# ga should be tidak
# dpt should be dapat
# kalo should be kalau
# ga should be tidak
# ka should be kak
# thn should be tahun
# udah should be sudah
# trs should be terus
# ka should be kak
# gak should be tidak
# brp should be berapa
# klo should be kalau
# brpa should be berapa
# kk should be kakak
# dah should be sudah
# kalo should be kalau
# nambah should be menambah
# ga should be tidak
# ga should be tidak
# ngga should be tidak
# brpa should be berapa
# gk should be tidak
# ga should be tidak
# kk should be kakak
# brpa should be berapa
# kk should be kakak
# ga should be tidak
# dapet should be dapat
# taun should be tahun
# ga should be tidak
# q should be aku
# sam should be sama
# brp should be berapa
# pake should be pakai
# gak should be tidak
# gak should be tidak
# gt should be begitu
# ngk should be tidak
# klo should be kalau
# pkai should be pakai
# g should be begitu
# ga should be tidak
# sisain should be menyisakan
# yah should be iya
# tingal should be tinggal
# ga should be tidak
# gak should be tidak
# gak should be tidak
# gak should be tidak
# udah should be sudah
# brpa should be berapa
# gak should be tidak
# kalo should be kalau
# k should be ke
# gak should be tidak
# pake should be pakai
# ga should be tidak
# nambah should be menambah
# ga should be tidak
# nambah should be menambah
# kalo should be kalau
# ga should be tidak
# minta should be meminta
# kalo should be kalau
# engga should be tidak
# brp should be berapa
# brp should be berapa
# ga should be tidak
# kalo should be kalau
# pake should be pakai
# nambah should be menambah
# ga should be tidak
# gak should be tidak
# kalo should be kalau
# nambah should be menambah
# nggak should be tidak
# nambah should be menambah
# kalo should be kalau
# doank should be doang
# g should be begitu
# ga should be tidak
# gak should be tidak
# g should be begitu
# x should be kali
# w should be saya
# s should be sih
# gk should be tidak
# y should be iya
# gimana should be bagaimana
# pengen should be mau
# kalo should be kalau
# nggk should be tidak
# kalo should be kalau
# ato should be atau
# gak should be tidak
# kalo should be kalau
# ga should be tidak
# ga should be tidak
# hallo should be halo
# ka should be kak
# gak should be tidak
# ka should be kak
# gak should be tidak
# ka should be kak
# ms should be masih
# blom should be belum
# w should be saya
# ka should be kak
# gk should be tidak
# gk should be tidak
# gak should be tidak
# ka should be kak
# ga should be tidak
# maen should be main
# ama should be sama
# trima should be terima
# ka should be kak
# yg should be yang
# brp should be berapa
# ga should be tidak
# yg should be yang
# brp should be berapa
# ngga should be tidak
# yg should be yang
# gimana should be bagaimana
# kalo should be kalau
# yah should be iya
# kalo should be kalau
# skrg should be sekarang
# kpn should be kapan
# gak should be tidak
# minta should be meminta
# udah should be sudah
# it should be itu
# utk should be  untuk
# k should be ke
# z should be saja
# ga should be tidak
# mb should be mbak
# klu should be kalau
# brapa should be berapa
# ngak should be tidak
# kalo should be kalau
# nambah should be menambah
# yg should be yang
# yg should be yang
# nggk should be tidak
# yah should be iya
# gitu should be begitu
# yg should be yang
# tpi should be tapi
# ama should be sama
# yg should be yang
# udah should be sudah
# ga should be tidak
# kalo should be kalau
# brp should be berapa
# kalo should be kalau
# nambah should be menambah
# udah should be sudah
# udah should be sudah
# x should be kali
# udah should be sudah
# bg should be abang
# k should be ke
# nga should be tidak
# yg should be yang
# yah should be iya
# kalo should be kalau
# brp should be berapa
# k should be ke
# ga should be tidak
# brp should be berapa
# nga should be tidak
# nambah should be menambah
# tambahin should be tambahkan
# gak should be tidak
# kenceng should be kencang
# ga should be tidak
# ap should be apa
# kalo should be kalau
# brp should be berapa
# jdi should be jadi
# ga should be tidak
# klo should be kalau
# trus should be terus
# ga should be tidak
# pake should be pakai
# brp should be berapa
# yg should be yang
# nambah should be menambah
# kalo should be kalau
# trus should be terus
# kalo should be kalau
# nambah should be menambah
# brp should be berapa
# gk should be tidak
# kalo should be kalau
# nambah should be menambah
# kalo should be kalau
# gk should be tidak
# kalo should be kalau
# ga should be tidak
# udh should be sudah
# jt should be juta
# udah should be sudah
# yah should be iya
# kalo should be kalau
# nambah should be menambah
# pake should be pakai
# kalo should be kalau
# brapa should be berapa
# gak should be tidak
# yg should be yang
# nambah should be menambah
# sma should be sama
# kalo should be kalau
# pake should be pakai
# gk should be tidak
# kalo should be kalau
# g should be begitu
# ama should be sama
# make should be memakai
# brp should be berapa
# gimana should be bagaimana
# y should be iya
# gapake should be tidak pakai
# brp should be berapa
# kalo should be kalau
# gak should be tidak
# pake should be pakai
# in should be ini
# ori should be orisinal
# kalo should be kalau
# brapa should be berapa
# kalo should be kalau
# g should be begitu
# kl should be kalau
# pake should be pakai
# jd should be jadi
# brp should be berapa
# kk should be kakak
# kalo should be kalau
# maen should be main
# ka should be kak
# yg should be yang
# ato should be atau
# boss should be bos
# yg should be yang
# ngga should be tidak
# ngga should be tidak
# ngga should be tidak
# pake should be pakai
# sm should be sama
# gk should be tidak
# kalo should be kalau
# kalo should be kalau
# pake should be pakai
# gak should be tidak
# dpt should be dapat
# yg should be yang
# milih should be memilih
# nggak should be tidak
# klau should be kalau
# w should be saya
# gak should be tidak
# ga should be tidak
# ga should be tidak
# gak should be tidak
# aja should be saja
# kalo should be kalau
# gk should be tidak
# gak should be tidak
# ma should be sama
# klo should be kalau
# brapa should be berapa
# jugak should be juga
# klo should be kalau
# brp should be berapa
# gak should be tidak
# jkt should be jakarta
# ngga should be tidak
# dmn should be dimana
# brp should be berapa
# klo should be kalau
# lg should be lagi
# kalo should be kalau
# gak should be tidak
# jt should be juta
# klo should be kalau
# brapa should be berapa
# gak should be tidak
# gak should be tidak
# g should be begitu
# jdi should be jadi
# ka should be kak
# trs should be terus
# brp should be berapa
# udah should be sudah
# klu should be kalau
# dg should be dengan
# a should be allah
# bs should be bisa
# kalo should be kalau
# nambah should be menambah
# d should be di
# gak should be tidak
# kk should be kakak
# ga should be tidak
# ka should be kak
# kalo should be kalau
# udah should be sudah
# yg should be yang
# tp should be tapi
# ga should be tidak
# aja should be saja
# yg should be yang
# bs should be bisa
# gak should be tidak
# kalo should be kalau
# klo should be kalau
# ga should be tidak
# ga should be tidak
# udh should be sudah
# tdr should be tidur
# kalo should be kalau
# pake should be pakai
# maen should be main
# gak should be tidak
# gak should be tidak
# udah should be sudah
# gk should be tidak
# sdh should be sudah
# blm should be belum
# brp should be berapa
# gimana should be bagaimana
# g should be begitu
# udah should be sudah
# aja should be saja
# nggak should be tidak
# dah should be sudah
# ga should be tidak
# yh should be iya
# udh should be sudah
# kalo should be kalau
# nambah should be menambah
# brapa should be berapa
# kk should be kakak
# gk should be tidak
# gimana should be bagaimana
# mo should be mau
# doank should be doang
# gk should be tidak
# gak should be tidak
# aja should be saja
# ga should be tidak
# gimana should be bagaimana
# ma should be sama
# gk should be tidak
# jd should be jadi
# brp should be berapa
# ka should be kak
# udah should be sudah
# blom should be belum
# gak should be tidak
# gitu should be begitu
# maen should be main
# gak should be tidak
# brpa should be berapa
# g should be begitu
# c should be sih
# brpa should be berapa
# dri should be dari
# dapet should be dapat
# aja should be saja
# yg should be yang
# ka should be kak
# gak should be tidak
# jd should be jadi
# kalo should be kalau
# ga should be tidak
# udh should be sudah
# klo should be kalau
# g should be begitu
# pake should be pakai
# jd should be jadi
# brpa should be berapa
# gimana should be bagaimana
# ka should be kak
# aja should be saja
# kaka should be kakak
# ga should be tidak
# nambah should be menambah
# gak should be tidak
# dh should be sudah
# gk should be tidak
# pake should be pakai
# kalo should be kalau
# ga should be tidak
# bg should be abang
# gak should be tidak
# bg should be abang
# brp should be berapa
# ka should be kak
# ga should be tidak
# yah should be iya
# gak should be tidak
# kyk should be seperti
# ga should be tidak
# gak should be tidak
# a should be allah
# dapet should be dapat
# sudh should be sudah
# dgn should be dengan
# iy should be iya
# udah should be sudah
# gak should be tidak
# g should be begitu
# ga should be tidak
# udah should be sudah
# gak should be tidak
# ga should be tidak
# udh should be sudah
# pke should be pakai
# ap should be apa
# udah should be sudah
# pake should be pakai
# pke should be pakai
# ka should be kak
# gk should be tidak
# udh should be sudah
# ga should be tidak
# ka should be kak
# klo should be kalau
# ga should be tidak
# kalo should be kalau
# kaya should be seperti
# gitu should be begitu
# gw should be saya
# kalo should be kalau
# ga should be tidak
# ngerti should be mengerti
# milih should be memilih
# pke should be pakai
# brp should be berapa
# maen should be main
# gak should be tidak
# halooo should be halo
# jt should be juta
# dapet should be dapat
# jt should be juta
# dapet should be dapat
# aja should be saja
# dah should be sudah
# dapet should be dapat
# ngga should be tidak
# mksih should be terima kasih
# kalo should be kalau
# mb should be mbak
# kalo should be kalau
# dipake should be dipakai
# ga should be tidak
# k should be ke
# k should be ke
# kalo should be kalau
# or should be orang
# udah should be sudah
# boss should be bos
# pake should be pakai
# ga should be tidak
# yg should be yang
# brpa should be berapa
# dapet should be dapat
# gak should be tidak
# ka should be kak
# kalo should be kalau
# gak should be tidak
# gak should be tidak
# bg should be abang
# gk should be tidak
# kalo should be kalau
# gak should be tidak
# gak should be tidak
# klo should be kalau
# pke should be pakai
# yg should be yang
# ga should be tidak
# tp should be tapi
# ga should be tidak
# mksd should be maksud
# y should be iya
# y should be iya
# x should be kali
# a should be allah
# kn should be kan
# jalanin should be menjalani
# x should be kali
# ga should be tidak
# bbrp should be beberapa
# gmna should be bagaimana
# nggak should be tidak
# utk should be  untuk
# udah should be sudah
# ato should be atau
# gtu should be begitu
# kalo should be kalau
# kalo should be kalau
# gak should be tidak
# aja should be saja
# gk should be tidak
# pake should be pakai
# gak should be tidak
# gak should be tidak
# ngga should be tidak
# gimana should be bagaimana
# gimana should be bagaimana
# ori should be orisinal
# dapet should be dapat
# kalo should be kalau
# nambah should be menambah
# gak should be tidak
# blm should be belum
# ga should be tidak
# jdi should be jadi
# brp should be berapa
# minta should be meminta
# sya should be saya
# ga should be tidak
# gak should be tidak
# kakkk should be kak
# lgsg should be langsung
# kalo should be kalau
# pake should be pakai
# yg should be yang
# ga should be tidak
# gk should be tidak
# brp should be berapa
# ori should be orisinal
# gmn should be bagaimana
# utk should be  untuk
# gak should be tidak
# gak should be tidak
# pake should be pakai
# g should be begitu
# kk should be kakak
# gnti should be ganti
# gitu should be begitu
# ka should be kak
# kalo should be kalau
# pake should be pakai
# kalo should be kalau
# ga should be tidak
# klo should be kalau
# ato should be atau
# ga should be tidak
# ka should be kak
# ga should be tidak
# tar should be nanti
# udh should be sudah
# ato should be atau
# blm should be belum
# abis should be habis
# pengen should be mau
# sm should be sama
# kaya should be seperti
# yg should be yang
# d should be di
# jg should be juga
# ga should be tidak
# yg should be yang
# gk should be tidak
# nambah should be menambah
# nambah should be menambah
# jg should be juga
# jdi should be jadi
# nambah should be menambah
# y should be iya
# nambah should be menambah
# brapa should be berapa
# udh should be sudah
# belom should be belum
# kenceng should be kencang
# ga should be tidak
# utk should be  untuk
# d should be di
# d should be di
# nunggu should be menunggu
# dapet should be dapat
# ga should be tidak
# dpt should be dapat
# brp should be berapa
# yg should be yang
# gmna should be bagaimana
# tu should be itu
# lah should be lagi
# sy should be saya
# brp should be berapa
# jk should be jika
# yg should be yang
# sdh should be sudah
# trmasuk should be termasuk
# hrs should be harus
# milih should be memilih
# brp should be berapa
# gt should be begitu
# aja should be saja
# kalo should be kalau
# dpt should be dapat
# sdh should be sudah
# dpt should be dapat
# yg should be yang
# udah should be sudah
# sy should be saya
# aja should be saja
# aja should be saja
# makasih should be terima kasih
# udah should be sudah
# ngedit should be mengedit
# ka should be kak
# yg should be yang
# kaka should be kakak
# sy should be saya
# pake should be pakai
# gimana should be bagaimana
# ga should be tidak
# bales should be balas
# brapa should be berapa
# sdh should be sudah
# yg should be yang
# gak should be tidak
# dpt should be dapat
# brp should be berapa
# gak should be tidak
# dapet should be dapat
# brp should be berapa
# yg should be yang
# dipake should be dipakai
# d should be di
# gak should be tidak
# brp should be berapa
# ka should be kak
# w should be saya
# in should be ini
# ap should be apa
# aj should be saja
# g should be begitu
# klo should be kalau
# gk should be tidak
# kk should be kakak
# brp should be berapa
# kalo should be kalau
# gk should be tidak
# gak should be tidak
# kaya should be seperti
# gitu should be begitu
# pake should be pakai
# ga should be tidak
# z should be saja
# gak should be tidak
# k should be ke
# gak should be tidak
# pake should be pakai
# gak should be tidak
# gak should be tidak
# udah should be sudah
# beneran should be benaran
# kalo should be kalau
# ga should be tidak
# sdh should be sudah
# g should be begitu
# gk should be tidak
# kalo should be kalau
# ngk should be tidak
# udah should be sudah
# gmn should be bagaimana
# ka should be kak
# g should be begitu
# klo should be kalau
# k should be ke
# gak should be tidak
# dar should be medar
# yg should be yang
# yg should be yang
# yg should be yang
# klo should be kalau
# aja should be saja
# trus should be terus
# gak should be tidak
# bagaimna should be bagaimana
# gak should be tidak
# maen should be main
# brp should be berapa
# nambah should be menambah
# gak should be tidak
# brp should be berapa
# yg should be yang
# sp should be sapa
# ka should be kak
# gak should be tidak
# kalo should be kalau
# nambah should be menambah
# brp should be berapa
# ga should be tidak
# w should be saya
# w should be saya
# nambah should be menambah
# brapa should be berapa
# liat should be lihat
# gak should be tidak
# kalo should be kalau
# gak should be tidak
# nambah should be menambah
# a should be allah
# ga should be tidak
# tmbh should be tambah
# nambah should be menambah
# brp should be berapa
# gak should be tidak
# nambah should be menambah
# nambah should be menambah
# bg should be abang
# a should be allah
# bg should be abang
# a should be allah
# kalo should be kalau
# jd should be jadi
# brp should be berapa
# udh should be sudah
# kalo should be kalau
# gk should be tidak
# gada should be tidak ada
# utk should be  untuk
# ga should be tidak
# nambah should be menambah
# lg should be lagi
# klo should be kalau
# spt should be seperti
# gak should be tidak
# yg should be yang
# kaya should be seperti
# mo should be mau
# ama should be sama
# udh should be sudah
# blm should be belum
# mh should be mah
# dpt should be dapat
# s should be sih
# udh should be sudah
# ga should be tidak
# gak should be tidak
# gk should be tidak
# ni should be nih
# sdh should be sudah
# yak should be iya
# brp should be berapa
# utk should be  untuk
# bs should be bisa
# minta should be meminta
# aja should be saja
# klo should be kalau
# brp should be berapa
# sy should be saya
# nambah should be menambah
# gk should be tidak
# gk should be tidak
# yah should be iya
# ngga should be tidak
# gak should be tidak
# jk should be jika
# jd should be jadi
# brp should be berapa
# kalo should be kalau
# kalo should be kalau
# ga should be tidak
# ga should be tidak
# maen should be main
# gk should be tidak
# dapet should be dapat
# kl should be kalau
# jd should be jadi
# ga should be tidak
# kalo should be kalau
# nonton should be menonton
# udah should be sudah
# pake should be pakai
# t should be ta
# gak should be tidak
# yg should be yang
# w should be saya
# pake should be pakai
# kalo should be kalau
# w should be saya
# brp should be berapa
# ga should be tidak
# g should be begitu
# yg should be yang
# w should be saya
# brp should be berapa
# brp should be berapa
# ato should be atau
# klo should be kalau
# klo should be kalau
# gk should be tidak
# kalo should be kalau
# gapake should be tidak pakai
# ga should be tidak
# nambah should be menambah
# gausah should be tidak usah
# dapet should be dapat
# brp should be berapa
# klo should be kalau
# brp should be berapa
# kalo should be kalau
# lg should be lagi
# gn should be begini
# klo should be kalau
# gk should be tidak
# klo should be kalau
# yg should be yang
# yg should be yang
# yg should be yang
# aja should be saja
# yg should be yang
# yaa should be iya
# kalo should be kalau
# x should be kali
# kalo should be kalau
# brpa should be berapa
# kalo should be kalau
# brp should be berapa
# kalo should be kalau
# brp should be berapa
# utk should be  untuk
# jdi should be jadi
# kalo should be kalau
# pake should be pakai
# c should be sih
# jd should be jadi
# brp should be berapa
# kalo should be kalau
# yg should be yang
# gk should be tidak
# dlu should be dulu
# yg should be yang
# kl should be kalau
# aja should be saja
# brp should be berapa
# yg should be yang
# kalo should be kalau
# jdi should be jadi
# jdi should be jadi
# kalo should be kalau
# brp should be berapa
# klo should be kalau
# jd should be jadi
# jd should be jadi
# brp should be berapa
# klo should be kalau
# yg should be yang
# dgn should be dengan
# jd should be jadi
# brp should be berapa
# klo should be kalau
# z should be saja
# a should be allah
# jdi should be jadi
# udh should be sudah
# lg should be lagi
# yah should be iya
# yg should be yang
# kaya should be seperti
# tpi should be tapi
# yah should be iya
# ngga should be tidak
# jt should be juta
# dateng should be datang
# brp should be berapa
# kalo should be kalau
# ga should be tidak
# yah should be iya
# ga should be tidak
# bs should be bisa
# ga should be tidak
# ud should be sudah
# utk should be  untuk
# y should be iya
# klo should be kalau
# yg should be yang
# brpa should be berapa
# klo should be kalau
# brp should be berapa
# x should be kali
# x should be kali
# x should be kali
# x should be kali
# x should be kali
# x should be kali
# x should be kali
# x should be kali
# x should be kali
# w should be saya
# x should be kali
# x should be kali
# in should be ini
# x should be kali
# x should be kali
# yg should be yang
# sm should be sama
# gk should be tidak
# nggak should be tidak
# gak should be tidak
# pake should be pakai
# a should be allah
# hr should be hari
# brp should be berapa
# nggak should be tidak
# hallo should be halo
# dateng should be datang
# kalo should be kalau
# yg should be yang
# brp should be berapa
# belom should be belum
# klo should be kalau
# brapa should be berapa
# jt should be juta
# yg should be yang
# ama should be sama
# jdi should be jadi
# brp should be berapa
# x should be kali
# x should be kali
# x should be kali
# w should be saya
# t should be ta
# x should be kali
# brpa should be berapa
# gak should be tidak
# sy should be saya
# dgn should be dengan
# dgn should be dengan
# utk should be  untuk
# brp should be berapa
# bs should be bisa
# tlg should be tolong
# yg should be yang
# brp should be berapa
# kalo should be kalau
# ga should be tidak
# gk should be tidak
# d should be di
# nambah should be menambah
# brp should be berapa
# ori should be orisinal
# aja should be saja
# yg should be yang
# gt should be begitu
# dpt should be dapat
# thn should be tahun
# gk should be tidak
# sm should be sama
# kalo should be kalau
# jd should be jadi
# udh should be sudah
# yg should be yang
# gk should be tidak
# klo should be kalau
# nambah should be menambah
# brp should be berapa
# ka should be kak
# yg should be yang
# sy should be saya
# udah should be sudah
# blm should be belum
# gak should be tidak
# sdh should be sudah
# ngga should be tidak
# nggak should be tidak
# kalo should be kalau
# gak should be tidak
# yaa should be iya
# ap should be apa
# gk should be tidak
# gini should be begini
# gak should be tidak
# gitu should be begitu
# ae should be saja
# gak should be tidak
# gak should be tidak
# yah should be iya
# nambah should be menambah
# brp should be berapa
# kalo should be kalau
# aja should be saja
# minta should be meminta
# dapet should be dapat
# brp should be berapa
# yg should be yang
# ga should be tidak
# kalo should be kalau
# kalo should be kalau
# ga should be tidak
# tambahin should be tambahkan
# donk should be dong
# dapet should be dapat
# aja should be saja
# dapet should be dapat
# gimana should be bagaimana
# dapet should be dapat
# gmn should be bagaimana
# ngk should be tidak
# dapet should be dapat
# ga should be tidak
# gak should be tidak
# ga should be tidak
# jd should be jadi
# kalo should be kalau
# dapet should be dapat
# kalo should be kalau
# y should be iya
# kalo should be kalau
# kalo should be kalau
# aja should be saja
# gk should be tidak
# bg should be abang
# gt should be begitu
# gt should be begitu
# g should be begitu
# ad should be ada
# dlu should be dulu
# dapet should be dapat
# nambah should be menambah
# brpa should be berapa
# ga should be tidak
# k should be ke
# kalo should be kalau
# kalo should be kalau
# ga should be tidak
# yah should be iya
# gak should be tidak
# dapet should be dapat
# aja should be saja
# utk should be  untuk
# ka should be kak
# yah should be iya
# klo should be kalau
# k should be ke
# dgn should be dengan
# kalo should be kalau
# udh should be sudah
# yg should be yang
# brp should be berapa
# ga should be tidak
# gk should be tidak
# maen should be main
# atw should be atau
# k should be ke
# k should be ke
# nambah should be menambah
# brp should be berapa
# dapet should be dapat
# brpa should be berapa
# kalo should be kalau
# gak should be tidak
# kalo should be kalau
# klo should be kalau
# ga should be tidak
# nambah should be menambah
# brp should be berapa
# dapet should be dapat
# aja should be saja
# dah should be sudah
# k should be ke
# dpn should be depan
# mo should be mau
# msh should be masih
# bs should be bisa
# thn should be tahun
# k should be ke
# dpn should be depan
# bs should be bisa
# gk should be tidak
# gak should be tidak
# gk should be tidak
# nggak should be tidak
# cm should be cuma
# bs should be bisa
# gak should be tidak
# ga should be tidak
# kalo should be kalau
# utk should be  untuk
# kalo should be kalau
# nda should be tidak
# yah should be iya
# sma should be sama
# gak should be tidak
# kalo should be kalau
# pake should be pakai
# gk should be tidak
# dapet should be dapat
# gak should be tidak
# kalo should be kalau
# yg should be yang
# 0        None
# 1        None
# 2        bisa
# 3        None
# 4        bisa
#          ...
# 12104    None
# 12105    None
# 12106    None
# 12107    None
# 12108    None
# Name: kata, Length: 12109, dtype: object

# %%
def replace_slang(word):
    # Replace each token if it matches a slang term
    steming_slang = slang_dict.get(word)
    if steming_slang == None:
        return word
    else:
        try:
            if(math.isnan(steming_slang)):
                return word
            else:
                return steming_slang
        except:
            return steming_slang

df_token['kata'] = df_token['kata'].apply(replace_slang)

# %%
# THis notebook is used to check if there is slang word in df_token
def check_slang_word(word):
    steming_slang = slang_dict.get(word)
    if steming_slang == None:
        return 
    else:
        try:
            if(math.isnan(steming_slang)):
                return
            else:
                print(f"{word} should be {steming_slang}")
                return 
        except:
            print(f"{word} should be {steming_slang}")
            return 
        
df_token['kata'].apply(check_slang_word)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 12104    None
# 12105    None
# 12106    None
# 12107    None
# 12108    None
# Name: kata, Length: 12109, dtype: object

# %% [markdown]
# <b>

# %% [markdown]
# #### ***3.7 Stemming***

# %% [markdown]
# ----

# %%
# Create object that use to stemming word in indonesia using Sastrawati
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
list_skip_steming_word = ['kinemaster','setingan','bekasi','seandainya','seting','rohan','lemot','kesing','diseting']

# %%
# Stemming word using sastrawi
def steming_word_sastrawi(word):
    stemmed_word = word
    if word not in list_skip_steming_word:
        stemmed_word = stemmer.stem(word)
    return stemmed_word

df_token['kata_steming'] = df_token['kata'].apply(steming_word_sastrawi)

# %%
# Steming using manual word
list_kata_dasar = ['setting','packing','offline','pc','seting','memory','software','ssd','halo','render','ongkir','ganti','upgrade','vga','mobo','case','casing','install','keyboard','ddr','processor','hdd','storage']
for kata_dasar in list_kata_dasar:
    df_token.loc[df_token['kata'].str.contains(kata_dasar),'kata'] = kata_dasar

# %%
# df_token.loc[df_token['kata'].str.contains('storage'),'kata']
# Out:
# 3616     storagenya
# 3897        storage
# 3900        storage
# 3967        storage
# 4246        storage
# 4351        storage
# 11725       storage
# Name: kata, dtype: object

# %%
# Check word before and after steming
test = df_token[df_token['kata'] != df_token['kata_steming']][['kata','kata_steming']].drop_duplicates()
test.to_csv('test_steming.csv',index=False)

# %% [markdown]
# #### ***3.8 Stopword***

# %%
# initiate object that use to remove stopword using sastrawi
stopword_factory = StopWordRemoverFactory()
stopword_remover = stopword_factory.create_stop_word_remover()

# %%
# Remove stopword in df_token saraswati
def remove_stopword(word):
    stopword_word = stopword_remover.remove(word)
    return stopword_word
    
df_token['kata_steming'] = df_token['kata_steming'].apply(remove_stopword)

# %%
# Check stoword in csv
test = df_token[df_token['kata_steming'] == ''][['kata']].drop_duplicates()
test.to_csv('test_stopword.csv',index=False)

# %%
df_token = df_token[df_token['kata_steming'] != '']

# %% [markdown]
# #### ***3.9 Labeling word tag with existing data***

# %%
df_token['kata'] = df_token['kata_steming']
df_token = df_token[['sentence','kata','tag']]
df_token
# Out:
# /var/folders/cr/8g19f6x13sn907v0ff4vkmm80000gn/T/ipykernel_19158/2607273015.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_token['kata'] = df_token['kata_steming']
#            sentence     kata tag
# 0         Kalimat 1    forza
# 1         Kalimat 1  horizon
# 3         Kalimat 1       om
# 5         Kalimat 1   sekali
# 7         Kalimat 1  install
# ...             ...      ...  ..
# 12101  Kalimat 1390      mau
# 12103  Kalimat 1390     ubah
# 12105  Kalimat 1390      min
# 12107  Kalimat 1391    ready
# 12108  Kalimat 1391      gan
#
# [8936 rows x 3 columns]

# %%
# import DatasetWithTagFinal csv
df_import = pd.read_csv("../dataset/DatasetWithTagFinal.csv")

# %%
def fill_tag(sentence,kata):
    tag = df_import[(df_import['sentence'] == sentence) & (df_import['kata'] == kata)][['tag']].values
    try:
        return tag[0][0]
    except:
        return ''

df_token['tag'] = df_token.apply(lambda row_data: fill_tag(row_data['sentence'],row_data['kata']),axis=1)

# %%
# Check if there are missing tag
df_token[(df_token['tag'] == '') | (df_token['tag'].isna())]
# Out:
#            sentence          kata tag
# 36        Kalimat 5     installin
# 555      Kalimat 68       ongkirx
# 826     Kalimat 105     rendering
# 854     Kalimat 109     settingan
# 874     Kalimat 111     ongkirnya
# ...             ...           ...  ..
# 11531  Kalimat 1325    offlinenya
# 11544  Kalimat 1327    packingnya
# 11890  Kalimat 1368      diseting
# 11961  Kalimat 1376     settingan
# 12043  Kalimat 1385  settingannya
#
# [91 rows x 3 columns]

# %% [markdown]
# #### ***3.10 Manual Labeling (If necessary)***

# %%
# def add_tag(kata,tag,sentence):
#     if kata == 'getar' :
#     # if kata == 'studio' and sentence == 'Kalimat 190':
#         return 'E-Device'
#     return tag
# df_token['tag'] = df_token.apply(lambda x: add_tag(x['kata'],x['tag'],x['sentence']), axis=1)

# %%
# df_token[df_token['tag'] == 'B-Aksesoris']

# %%
# df_token.groupby('sentence').count()

# %%
# df_token['tag'].unique()

# %%
# df_token[df_token['kata'] == 'getar']

# %%
# df_token[df_token['tag'].isna()][df_token['sentence'] == 'Kalimat 1237']

# %%
# df.iloc[1236]['question']

# %%
# df_token[(df_token['tag'] == '') | (df_token['tag'].isna())]

# %%
# test = df_token[(df_token['tag'] == '') | (df_token['tag'].isna())][['kata']]
# test['kata2'] = test['kata']
# # test
# test.groupby('kata').count().sort_values(by='kata2',ascending=False)

# %%
# df_token.to_csv("../dataset/DatasetWithTagFinal.csv",index=False)

# %% [markdown]
# ----
# ----
