# %%
import pandas as pd
import json

# %%
df = pd.read_csv("../dataset/HabisStem.csv")

# %%
df
# Out:
#       Unnamed: 0                                     stemmed_tokens
# 0              0         ['forza', 'horizon', '5', 'om', 'install']
# 1              1                     ['gan', 'pc', 'only', 'dalem']
# 2              2  ['gan', 'maenin', 'game', 'iya', 'fc', '24', '...
# 3              3                          ['gan', 'pb', 'gta', '5']
# 4              4  ['installin', 'ets2', 'gta', 'roleplay', 'sisa...
# ...          ...                                                ...
# 1387        1387  ['gan', 'pakai', 'game', 'microsoft', 'flight'...
# 1388        1388  ['min', 'minecraft', 'fps', 'tolong', 'min', '...
# 1389        1389  ['min', 'hardisk-', 'ubah', '1tb', 'tambah', '...
# 1390        1390                                    ['ubah', 'min']
# 1391        1391                                   ['ready', 'gan']
#
# [1392 rows x 2 columns]

# %%
list_result = []
index = 0
def convert(list_word):
    list_word.replace("'",'"')
    print(list_word)
    # for word in list_word:
    #     data = {
    #         'word':word,
    #     }
    #     list_result.append(data)

df['stemmed_tokens'].apply(convert)
# Out:
# ['forza', 'horizon', '5', 'om', 'install']
# ['gan', 'pc', 'only', 'dalem']
# ['gan', 'maenin', 'game', 'iya', 'fc', '24', 'call', 'of', 'duty', 'modern', 'warfare2']
# ['gan', 'pb', 'gta', '5']
# ['installin', 'ets2', 'gta', 'roleplay', 'sisa', 'kosong']
# ['bang', 'beli', 'gamenya', 'ilangin', 'ajar', 'download', 'bang']
# ['tambah', 'hdd', '1', 'tera']
# ['gan', 'komponen', 'pc', 'orisinal']
# ['gan', 'windows', '10', 'pro', 'original']
# ['monitor', 'req', 'hp24c', 'gan']
# ['gta', 'roplay', 'kuat', 'gan']
# ['req', 'game']
# ['gan', 'toko', 'asli', 'mana']
# ['assalamualaikum', 'kak', 'maaf', 'kak', 'beli', 'bayar', 'cicil', 'seumpma', 'cicil', 'ambil', '12', 'buln', 'seumpm', 'uang', 'lunasin', 'biar', 'sethun']
# ['tegang', 'rumah', 'cuman', '450', 'kuat']
# ['i7', '860', 'bagus', '', 'beli', 'cuman', 'ragu', 'gen']
# ['gan', 'proxessornya', 'gen', 'gen', '8', 'kah']
# ['sore', 'gan', 'pc', 'terima', 'kasih']
# ['game', 'forza', 'horizon']
# ['monitor', 'ganti', 'curve']
# ...

# %%
"['forza', 'horizon', '5', 'om', 'install']".replace("'",'"')
# Out:
# ['forza', 'horizon', '5', 'om', 'install']

# %%
list_result
# Out:
# [{'sentence': 0, 'word': '['},
#  {'sentence': 0, 'word': "'"},
#  {'sentence': 0, 'word': 'f'},
#  {'sentence': 0, 'word': 'o'},
#  {'sentence': 0, 'word': 'r'},
#  {'sentence': 0, 'word': 'z'},
#  {'sentence': 0, 'word': 'a'},
#  {'sentence': 0, 'word': "'"},
#  {'sentence': 0, 'word': ','},
#  {'sentence': 0, 'word': ' '},
#  {'sentence': 0, 'word': "'"},
#  {'sentence': 0, 'word': 'h'},
#  {'sentence': 0, 'word': 'o'},
#  {'sentence': 0, 'word': 'r'},
#  {'sentence': 0, 'word': 'i'},
#  {'sentence': 0, 'word': 'z'},
#  {'sentence': 0, 'word': 'o'},
#  {'sentence': 0, 'word': 'n'},
#  {'sentence': 0, 'word': "'"},
#  {'sentence': 0, 'word': ','},
#  {'sentence': 0, 'word': ' '},
#  {'sentence': 0, 'word': "'"},
#  {'sentence': 0, 'word': '5'},
#  {'sentence': 0, 'word': "'"},
#  {'sentence': 0, 'word': ','},
#  {'sentence': 0, 'word': ' '},
#  {'sentence': 0, 'word': "'"},
#  {'sentence': 0, 'word': 'o'},
#  {'sentence': 0, 'word': 'm'},
#  {'sentence': 0, 'word': "'"},
# ...
